# %% [markdown]
# # Importaciones y definiciones

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from fastapi import FastAPI

# %% [markdown]
# #Carga de dataset
# Analizar las hojas del archivo Excel proporcionado para comprender su estructura y contenido.

# %%
import pandas
int_Acc_vel_loc_sinrangos_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Acc_vel_loc_sinrangos')
int_Velocidad_sin_Rangos_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Velocidad_sin_Rangos')
int_Accesos_tecnologia_localidad_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Accesos_tecnologia_localidad')
int_Velocidad_porciento_por_prov_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Velocidad % por prov')
int_Totales_VMD_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Totales VMD')
int_Totales_Accesos_Por_Tecnología_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Totales Accesos Por Tecnología')
int_Accesos_Por_Tecnología_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Accesos Por Tecnología')
int_Penetracion_poblacion_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Penetración-poblacion')
int_Penetracion_hogares_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Penetracion-hogares')
int_Penetracion_totales_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Penetracion-totales')
int_Totales_Accesos_por_rango_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Totales Accesos por rango')
int_Accesos_por_rangos_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Accesos por rangos')
int_Dial_Baf_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Dial-BAf')
int_Totales_Dial_Baf_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Totales Dial-BAf')
int_Ingresos_df = pandas.read_excel('data/Internet.xlsx', sheet_name='Ingresos ')

# %% [markdown]
# Resumen inicial: Examina las primeras filas y estructura de los datos.

# %%
print(int_Acc_vel_loc_sinrangos_df.head())  # Muestra las primeras filas
print(int_Acc_vel_loc_sinrangos_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Acc_vel_loc_sinrangos_df.describe())  # Estadísticas básicas
# Out:
#         Partido   Localidad  link Indec Velocidad (Mbps)  Provincia  Accesos
# 0  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       0.00      1.0
# 1  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       0.50      2.0
# 2  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       0.75     19.0
# 3  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       3.00     85.0
# 4  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       3.50    145.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18864 entries, 0 to 18863
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Partido           18864 non-null  object
#  1   Localidad         18864 non-null  object
#  2   link Indec        18863 non-null  object
#  3   Velocidad (Mbps)  18864 non-null  object
#  4   Provincia         18864 non-null  float64
#  5   Accesos           18857 non-null  float64
# ...

# %%
print(int_Velocidad_sin_Rangos_df.head())  # Muestra las primeras filas
print(int_Velocidad_sin_Rangos_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Velocidad_sin_Rangos_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre     Provincia  Velocidad  Accesos
# 0  2024          2  BUENOS AIRES       75.0     1062
# 1  2024          2  BUENOS AIRES       59.0       59
# 2  2024          2  BUENOS AIRES      480.0        5
# 3  2024          2  BUENOS AIRES        3.5    41735
# 4  2024          2  BUENOS AIRES       18.0     1042
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18884 entries, 0 to 18883
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Año        18884 non-null  int64
#  1   Trimestre  18884 non-null  int64
#  2   Provincia  18884 non-null  object
#  3   Velocidad  18874 non-null  float64
#  4   Accesos    18884 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 737.8+ KB
# None
#                 Año     Trimestre     Velocidad       Accesos
# count  18884.000000  18884.000000  18874.000000  1.888400e+04
# mean    2021.017104      2.477653     96.171156  1.412328e+04
# ...

# %%
print(int_Accesos_tecnologia_localidad_df.head())  # Muestra las primeras filas
print(int_Accesos_tecnologia_localidad_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Accesos_tecnologia_localidad_df.describe())  # Estadísticas básicas
# Out:
#       Provincia     Partido   Localidad    Tecnologia Link Indec  Accesos
# 0  BUENOS AIRES  25 de Mayo  25 de Mayo          ADSL    6854100    755.0
# 1  BUENOS AIRES  25 de Mayo  25 de Mayo    CABLEMODEM    6854100   4600.0
# 2  BUENOS AIRES  25 de Mayo  25 de Mayo  FIBRA OPTICA    6854100      2.0
# 3  BUENOS AIRES  25 de Mayo  25 de Mayo     SATELITAL    6854100    742.0
# 4  BUENOS AIRES  25 de Mayo  25 de Mayo      WIRELESS    6854100    727.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7753 entries, 0 to 7752
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Provincia   7753 non-null   object
#  1   Partido     7753 non-null   object
#  2   Localidad   7753 non-null   object
#  3   Tecnologia  7753 non-null   object
#  4   Link Indec  7753 non-null   object
#  5   Accesos     7747 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 363.6+ KB
# None
#             Accesos
# ...

# %%
print(int_Velocidad_porciento_por_prov_df.head())  # Muestra las primeras filas
print(int_Velocidad_porciento_por_prov_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Velocidad_porciento_por_prov_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre        Provincia  Mbps (Media de bajada)
# 0  2024          2     Buenos Aires                  157.41
# 1  2024          2  Capital Federal                  233.01
# 2  2024          2        Catamarca                   97.38
# 3  2024          2            Chaco                  107.76
# 4  2024          2           Chubut                   21.67
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     1008 non-null   int64
#  1   Trimestre               1008 non-null   int64
#  2   Provincia               1008 non-null   object
#  3   Mbps (Media de bajada)  1008 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.6+ KB
# None
#                Año    Trimestre  Mbps (Media de bajada)
# count  1008.000000  1008.000000             1008.000000
# ...

# %%
print(int_Totales_VMD_df.head())  # Muestra las primeras filas
print(int_Totales_VMD_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Totales_VMD_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre  Mbps (Media de bajada)    Trimestre.1
# 0  2024          2                  139.25   Abr-Jun 2024
# 1  2024          1                  139.15   Ene-Mar 2024
# 2  2023          4                  139.04   Oct-Dic 2023
# 3  2023          3                  129.67  Jul-Sept 2023
# 4  2023          2                  123.95   Abr-Jun 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     42 non-null     int64
#  1   Trimestre               42 non-null     int64
#  2   Mbps (Media de bajada)  42 non-null     float64
#  3   Trimestre.1             42 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.4+ KB
# None
#                Año  Trimestre  Mbps (Media de bajada)
# count    42.000000  42.000000               42.000000
# ...

# %%
print(int_Totales_Accesos_Por_Tecnología_df.head())  # Muestra las primeras filas
print(int_Totales_Accesos_Por_Tecnología_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Totales_Accesos_Por_Tecnología_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0  2024          2   733491     5867504       4169958    593197  191957
# 1  2024          1   774475     5986957       4015101    598682  257941
# 2  2023          4   836390     6022532       3908183    585760  194796
# 3  2023          3   897895     6018832       3708718    581436  200027
# 4  2023          2  1006509     5997149       3463988    581823  202428
#
#       Total        Periodo
# 0  11556107   Abr-Jun 2024
# 1  11633156   Ene-Mar 2024
# 2  11547661   Oct-Dic 2023
# 3  11406908  Jul-Sept 2023
# 4  11251897   Abr-Jun 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           42 non-null     int64
#  1   Trimestre     42 non-null     int64
#  2   ADSL          42 non-null     int64
#  3   Cablemodem    42 non-null     int64
# ...

# %%
print(int_Accesos_Por_Tecnología_df.head())  # Muestra las primeras filas
print(int_Accesos_Por_Tecnología_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Accesos_Por_Tecnología_df.describe())  # Estadísticas básicas
# Out:
#     Año Trimestre        Provincia      ADSL  Cablemodem  Fibra óptica  \
# 0  2024         2     Buenos Aires  214055.0   2722466.0     1849476.0
# 1  2024         2  Capital Federal   54102.0   1144781.0      230402.0
# 2  2024         2        Catamarca    4951.0     10303.0       58355.0
# 3  2024         2            Chaco    9448.0     57935.0       68944.0
# 4  2024         2           Chubut   25955.0     80704.0       26516.0
#
#    Wireless    Otros      Total
# 0  138638.0  64745.0  4989380.0
# 1    4493.0  29821.0  1463599.0
# 2    1384.0     81.0    75074.0
# 3    8407.0   2358.0   147092.0
# 4   31118.0   9930.0   174223.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           1008 non-null   object
#  1   Trimestre     1008 non-null   object
#  2   Provincia     1007 non-null   object
# ...

# %%
print(int_Penetracion_poblacion_df.head())  # Muestra las primeras filas
print(int_Penetracion_poblacion_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Penetracion_poblacion_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hab
# 0  2024          2     Buenos Aires                     27.43
# 1  2024          2  Capital Federal                     47.44
# 2  2024          2        Catamarca                     17.50
# 3  2024          2            Chaco                     11.78
# 4  2024          2           Chubut                     26.46
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Año                       1000 non-null   int64
#  1   Trimestre                 1000 non-null   int64
#  2   Provincia                 1000 non-null   object
#  3   Accesos por cada 100 hab  1000 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.4+ KB
# None
#                Año    Trimestre  Accesos por cada 100 hab
# ...

# %%
print(int_Penetracion_hogares_df.head())  # Muestra las primeras filas
print(int_Penetracion_hogares_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Penetracion_hogares_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2024          2     Buenos Aires                         79.84
# 1  2024          2  Capital Federal                        116.37
# 2  2024          2        Catamarca                         68.81
# 3  2024          2            Chaco                         44.06
# 4  2024          2           Chubut                         86.33
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           1000 non-null   int64
#  1   Trimestre                     1000 non-null   int64
#  2   Provincia                     1000 non-null   object
#  3   Accesos por cada 100 hogares  1000 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.4+ KB
# None
# ...

# %%
print(int_Penetracion_totales_df.head())  # Muestra las primeras filas
print(int_Penetracion_totales_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Penetracion_totales_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre  Accesos por cada 100 hogares  Accesos por cada 100 hab  \
# 0  2024          2                         78.13                     24.57
# 1  2024          1                         78.89                     24.79
# 2  2023          4                         78.56                     24.66
# 3  2023          3                         77.84                     24.41
# 4  2023          2                         77.02                     24.14
#
#          Periodo
# 0   Abr-Jun 2024
# 1   Ene-Mar 2024
# 2   Oct-Dic 2023
# 3  Jul-Sept 2023
# 4   Abr-Jun 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           42 non-null     int64
#  1   Trimestre                     42 non-null     int64
#  2   Accesos por cada 100 hogares  42 non-null     float64
# ...

# %%
print(int_Totales_Accesos_por_rango_df.head())  # Muestra las primeras filas
print(int_Totales_Accesos_por_rango_df.info())  # Detalles sobre columnas y tipos de datos
print(int_Totales_Accesos_por_rango_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0  2024          2           28151                    67024
# 1  2024          1           28801                    69355
# 2  2023          4           29708                    71742
# 3  2023          3           30274                    80609
# 4  2023          2           30827                    79405
#
#    Entre 1 Mbps y 6 Mbps  Entre 6 Mbps y 10 Mbps  Entre 10 Mbps y 20 Mbps  \
# 0                 840200                  911374                   662649
# 1                 866152                  950930                   672155
# 2                 900253                  978108                   697232
# 3                 945608                  998725                   720084
# 4                 963510                 1028250                   734125
#
#    Entre 20 Mbps y 30 Mbps  Más de 30 Mbps   OTROS     Total
# 0                   348253         8357088  341368  11556107
# ...

# %%
print(int_Accesos_por_rangos_df .head())  # Muestra las primeras filas
print(int_Accesos_por_rangos_df .info())  # Detalles sobre columnas y tipos de datos
print(int_Accesos_por_rangos_df .describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2024          2     Buenos Aires         25287.0              23034.0
# 1  2024          2  Capital Federal           518.0               4122.0
# 2  2024          2        Catamarca            72.0                164.0
# 3  2024          2            Chaco           236.0                349.0
# 4  2024          2           Chubut           125.0               1139.0
#
#    + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0           222627.0            221660.0             244528.0
# 1            24539.0             40296.0              33158.0
# 2             2660.0              3093.0               3799.0
# 3            14594.0              8336.0               6208.0
# 4            43699.0             31971.0              22696.0
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps     OTROS      Total
# 0             106302.0  4020395.0  125547.0  4989380.0
# ...

# %%
print(int_Dial_Baf_df .head())  # Muestra las primeras filas
print(int_Dial_Baf_df .info())  # Detalles sobre columnas y tipos de datos
print(int_Dial_Baf_df .describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre        Provincia  Banda ancha fija  Dial up    Total
# 0  2024          2     Buenos Aires           4983480   5900.0  4989380
# 1  2024          2  Capital Federal           1461549   2050.0  1463599
# 2  2024          2        Catamarca             75073      1.0    75074
# 3  2024          2            Chaco            147087      5.0   147092
# 4  2024          2           Chubut            173366    857.0   174223
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1992 entries, 0 to 1991
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               1992 non-null   int64
#  1   Trimestre         1992 non-null   int64
#  2   Provincia         1992 non-null   object
#  3   Banda ancha fija  1992 non-null   int64
#  4   Dial up           1988 non-null   float64
#  5   Total             1992 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# ...

# %%
print(int_Totales_Dial_Baf_df .head())  # Muestra las primeras filas
print(int_Totales_Dial_Baf_df .info())  # Detalles sobre columnas y tipos de datos
print(int_Totales_Dial_Baf_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre  Banda ancha fija  Dial up     Total        Periodo
# 0  2024          2          11544314    11793  11556107   Abr-Jun 2024
# 1  2024          1          11621363    11793  11633156   Ene-Mar 2024
# 2  2023          4          11535868    11793  11547661   Oct-Dic 2023
# 3  2023          3          11395115    11793  11406908  Jul-Sept 2023
# 4  2023          2          11239781    12116  11251897   Abr-Jun 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               42 non-null     int64
#  1   Trimestre         42 non-null     int64
#  2   Banda ancha fija  42 non-null     int64
#  3   Dial up           42 non-null     int64
#  4   Total             42 non-null     int64
#  5   Periodo           42 non-null     object
# dtypes: int64(5), object(1)
# memory usage: 2.1+ KB
# None
# ...

# %%
print(int_Ingresos_df .head())  # Muestra las primeras filas
print(int_Ingresos_df .info())  # Detalles sobre columnas y tipos de datos
print(int_Ingresos_df.describe())  # Estadísticas básicas
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0  2024          2               4.420322e+08   Abr-Jun 2024
# 1  2024          1               3.461990e+08   Ene-Mar 2024
# 2  2023          4               1.673760e+08   Oct-Dic 2023
# 3  2023          3               1.331066e+08  Jul-Sept 2023
# 4  2023          2               1.180603e+08   Jun-Mar 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        42 non-null     int64
#  1   Trimestre                  42 non-null     int64
#  2   Ingresos (miles de pesos)  42 non-null     float64
#  3   Periodo                    42 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.4+ KB
# None
#                Año  Trimestre  Ingresos (miles de pesos)
# ...

# %% [markdown]
# Valores nulos: Identifica si hay datos faltantes

# %%
print(int_Acc_vel_loc_sinrangos_df.isnull().sum())
# Out:
# Partido             0
# Localidad           0
# link Indec          1
# Velocidad (Mbps)    0
# Provincia           0
# Accesos             7
# dtype: int64

# %%
print(int_Velocidad_sin_Rangos_df.isnull().sum())
# Out:
# Año           0
# Trimestre     0
# Provincia     0
# Velocidad    10
# Accesos       0
# dtype: int64

# %%
print(int_Accesos_tecnologia_localidad_df.isnull().sum())
# Out:
# Provincia     0
# Partido       0
# Localidad     0
# Tecnologia    0
# Link Indec    0
# Accesos       6
# dtype: int64

# %%
print(int_Velocidad_porciento_por_prov_df.isnull().sum())
# Out:
# Año                       0
# Trimestre                 0
# Provincia                 0
# Mbps (Media de bajada)    0
# dtype: int64

# %%
print(int_Totales_VMD_df .isnull().sum())
# Out:
# Año                       0
# Trimestre                 0
# Mbps (Media de bajada)    0
# Trimestre.1               0
# dtype: int64

# %%
print(int_Totales_Accesos_Por_Tecnología_df .isnull().sum())
# Out:
# Año             0
# Trimestre       0
# ADSL            0
# Cablemodem      0
# Fibra óptica    0
# Wireless        0
# Otros           0
# Total           0
# Periodo         0
# dtype: int64

# %%
print(int_Accesos_Por_Tecnología_df .isnull().sum())
# Out:
# Año             1
# Trimestre       1
# Provincia       2
# ADSL            2
# Cablemodem      2
# Fibra óptica    2
# Wireless        2
# Otros           2
# Total           2
# dtype: int64

# %%
print(int_Penetracion_poblacion_df .isnull().sum())
# Out:
# Año                         0
# Trimestre                   0
# Provincia                   0
# Accesos por cada 100 hab    0
# dtype: int64

# %%
print(int_Penetracion_hogares_df .isnull().sum())
# Out:
# Año                             0
# Trimestre                       0
# Provincia                       0
# Accesos por cada 100 hogares    0
# dtype: int64

# %%
print(int_Penetracion_totales_df .isnull().sum())
# Out:
# Año                             0
# Trimestre                       0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Periodo                         0
# dtype: int64

# %%
print(int_Totales_Accesos_por_rango_df .isnull().sum())
# Out:
# Año                        0
# Trimestre                  0
# Hasta 512 kbps             0
# Entre 512 Kbps y 1 Mbps    0
# Entre 1 Mbps y 6 Mbps      0
# Entre 6 Mbps y 10 Mbps     0
# Entre 10 Mbps y 20 Mbps    0
# Entre 20 Mbps y 30 Mbps    0
# Más de 30 Mbps             0
# OTROS                      0
# Total                      0
# dtype: int64

# %%
print(int_Accesos_por_rangos_df .isnull().sum())
# Out:
# Año                    0
# Trimestre              0
# Provincia              0
# HASTA 512 kbps         0
# + 512 Kbps - 1 Mbps    0
# + 1 Mbps - 6 Mbps      0
# + 6 Mbps - 10 Mbps     0
# + 10 Mbps - 20 Mbps    0
# + 20 Mbps - 30 Mbps    0
# + 30 Mbps              0
# OTROS                  6
# Total                  0
# dtype: int64

# %%
print(int_Dial_Baf_df .isnull().sum())
# Out:
# Año                 0
# Trimestre           0
# Provincia           0
# Banda ancha fija    0
# Dial up             4
# Total               0
# dtype: int64

# %%
print(int_Totales_Dial_Baf_df .isnull().sum())
# Out:
# Año                 0
# Trimestre           0
# Banda ancha fija    0
# Dial up             0
# Total               0
# Periodo             0
# dtype: int64

# %%
print(int_Ingresos_df .isnull().sum())
# Out:
# Año                          0
# Trimestre                    0
# Ingresos (miles de pesos)    0
# Periodo                      0
# dtype: int64

# %% [markdown]
# Distribución de valores: Analiza la distribución de variables numéricas.

# %%
int_Acc_vel_loc_sinrangos_df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Velocidad_sin_Rangos_df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Accesos_tecnologia_localidad_df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Velocidad_porciento_por_prov_df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Totales_VMD_df .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Totales_Accesos_Por_Tecnología_df .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Accesos_Por_Tecnología_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Penetracion_poblacion_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Penetracion_hogares_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Penetracion_totales_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Totales_Accesos_por_rango_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Accesos_por_rangos_df  .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Dial_Baf_df .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Totales_Dial_Baf_df .hist(bins=50, figsize=(10, 8))
plt.show()

# %%
int_Ingresos_df .hist(bins=50, figsize=(10, 8))
plt.show()

# %% [markdown]
# Visualizaciones clave: Crea gráficos como diagramas de dispersión o cajas.

# %%
int_Acc_vel_loc_sinrangos_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Velocidad_sin_Rangos_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Accesos_tecnologia_localidad_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Velocidad_porciento_por_prov_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Totales_VMD_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Totales_Accesos_Por_Tecnología_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Accesos_Por_Tecnología_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Penetracion_poblacion_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Penetracion_hogares_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Penetracion_totales_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Totales_Accesos_por_rango_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Accesos_por_rangos_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Dial_Baf_df.plot(kind='box', figsize=(10, 8))
plt.show()

# %%
int_Ingresos_df.plot(kind='box', figsize=(10, 8))
plt.show()
